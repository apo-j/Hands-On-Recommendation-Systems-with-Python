# %%
import pandas as pd
# Load the Iris dataset into Pandas DataFrame
iris = pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data", 
                 names=['sepal_length','sepal_width','petal_length','petal_width','class'])

#Display the head of the dataframe
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width        class
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
#Import Standard Scaler from scikit-learn
from sklearn.preprocessing import StandardScaler

#Separate the features and the class
X = iris.drop('class', axis=1)
y = iris['class']

# Scale the features of X
X = pd.DataFrame(StandardScaler().fit_transform(X), 
                 columns = ['sepal_length','sepal_width','petal_length','petal_width'])

X.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0     -0.900681     1.032057     -1.341272    -1.312977
# 1     -1.143017    -0.124958     -1.341272    -1.312977
# 2     -1.385353     0.337848     -1.398138    -1.312977
# 3     -1.506521     0.106445     -1.284407    -1.312977
# 4     -1.021849     1.263460     -1.341272    -1.312977

# %%
#Import PCA
from sklearn.decomposition import PCA

#Intialize a PCA object to transform into the 2D Space.
pca = PCA(n_components=2)

#Apply PCA
pca_iris = pca.fit_transform(X)
pca_iris = pd.DataFrame(data = pca_iris, columns = ['PC1', 'PC2'])

pca_iris.head()
# Out:
#         PC1       PC2
# 0 -2.264542  0.505704
# 1 -2.086426 -0.655405
# 2 -2.367950 -0.318477
# 3 -2.304197 -0.575368
# 4 -2.388777  0.674767

# %%
import seaborn as sns
#Concatenate the class variable
pca_iris = pd.concat([pca_iris, y], axis = 1)

#Display the scatterplot
sns.lmplot(x='PC1', y='PC2', data=pca_iris, hue='class', fit_reg=False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Users/jyang03/.virtualenvs/ds/lib/python3.7/site-packages/seaborn/utils.py in categorical_order(values, order)
#     525             try:
# --> 526                 order = values.cat.categories
#     527             except (TypeError, AttributeError):
#
# /Users/jyang03/.virtualenvs/ds/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#
# AttributeError: 'DataFrame' object has no attribute 'cat'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# /Users/jyang03/.virtualenvs/ds/lib/python3.7/site-packages/seaborn/utils.py in categorical_order(values, order)
#     528                 try:
# --> 529                     order = values.unique()
#     530                 except AttributeError:
#
# /Users/jyang03/.virtualenvs/ds/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#
# AttributeError: 'DataFrame' object has no attribute 'unique'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-25e6770c7676> in <module>()
#       4
#       5 #Display the scatterplot
# ----> 6 sns.lmplot(x='PC1', y='PC2', data=pca_iris, hue='class', fit_reg=False)
#
# /Users/jyang03/.virtualenvs/ds/lib/python3.7/site-packages/seaborn/regression.py in lmplot(x, y, data, hue, col, row, palette, col_wrap, height, aspect, markers, sharex, sharey, hue_order, col_order, row_order, legend, legend_out, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, x_jitter, y_jitter, scatter_kws, line_kws, size)
#     556                        hue_order=hue_order, height=height, aspect=aspect,
#     557                        col_wrap=col_wrap, sharex=sharex, sharey=sharey,
# --> 558                        legend_out=legend_out)
#     559
#     560     # Add the markers here as FacetGrid has figured out how many levels of the
#
# /Users/jyang03/.virtualenvs/ds/lib/python3.7/site-packages/seaborn/axisgrid.py in __init__(self, data, row, col, hue, col_wrap, sharex, sharey, height, aspect, palette, row_order, col_order, hue_order, hue_kws, dropna, legend_out, despine, margin_titles, xlim, ylim, subplot_kws, gridspec_kws, size)
#     235             hue_names = None
#     236         else:
# --> 237             hue_names = utils.categorical_order(data[hue], hue_order)
#     238
#     239         colors = self._get_palette(data, hue, hue_order, palette)
#
# /Users/jyang03/.virtualenvs/ds/lib/python3.7/site-packages/seaborn/utils.py in categorical_order(values, order)
#     529                     order = values.unique()
#     530                 except AttributeError:
# --> 531                     order = pd.unique(values)
#     532                 try:
#     533                     np.asarray(values).astype(np.float)
#
# /Users/jyang03/.virtualenvs/ds/lib/python3.7/site-packages/pandas/core/algorithms.py in unique(values)
#     350     """
#     351
# --> 352     values = _ensure_arraylike(values)
#     353
#     354     if is_extension_array_dtype(values):
#
# /Users/jyang03/.virtualenvs/ds/lib/python3.7/site-packages/pandas/core/algorithms.py in _ensure_arraylike(values)
#     170             if isinstance(values, tuple):
#     171                 values = list(values)
# --> 172             values = construct_1d_object_array_from_listlike(values)
#     173         else:
#     174             values = np.asarray(values)
#
# /Users/jyang03/.virtualenvs/ds/lib/python3.7/site-packages/pandas/core/dtypes/cast.py in construct_1d_object_array_from_listlike(values)
#    1212     # making a 1D array that contains list-likes is a bit tricky:
#    1213     result = np.empty(len(values), dtype='object')
# -> 1214     result[:] = values
#    1215     return result
#    1216
#
# ValueError: could not broadcast input array from shape (150,2) into shape (150)
